# %% [markdown]
# # Energy and frequency
#
# With Planck's constant $h$, we write the relation between energy and frequency as:
#
# $$E = hf$$

# %% [markdown]
# $$E=hc/\lambda$$

# %% [markdown]
# $$F=G\frac{m_1m_2}{r^2}$$

# %% [markdown]
# $$sin(2x)=2sin(x)cos(x)=\frac{2tan(x)}{1+{tan}^2(x)}$$

# %%
from math import *
a=radians(30)
val1=sin(2*a)
val2=2*sin(a)*cos(a)
val3=(2*tan(a))/(1+tan(a)**2)
if val1==val2 and val2==val3:
    print('true')
else:
    print('false')
# Out:
# true

# %% [markdown]
# $$\displaystyle\sum^{\infty}_{k=0} \frac{1}{4k^2-1}=\frac{1}{2}$$
# $$\int_0^{\pi}e^{ix}dx=2i$$

# %%
from IPython.display import display, Math
from math import sin, pi

x = 9
Lambda = 0.5

s = rf"\sqrt({x}) = {x**0.5}\ and \sin(\lambda \pi)={sin(Lambda*pi)}"
print(s)
m = Math(s)
display(m)
# Out:
# \sqrt(9) = 3.0\ and \sin(\lambda \pi)=1.0
# $\displaystyle \sqrt(9) = 3.0\ and \sin(\lambda \pi)=1.0$

# %%
from math import exp, log
statement=True
i=0
while i<100:
    if int(exp(log(x)))!=x:
        statement=False
    i+=1
print(statement)
# Out:
# True

# %%
from math import *
a=factorial(100)
print(a)
# Out:
# 93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000

# %%
from math import atan2
y=3
x=2
phi=atan2(y,x)
t=tan(phi)
print(y/x)
print(t)
# Out:
# 1.5
# 1.5

# %%
from math import atan2, degrees
x=float(input('Enter x: '))
y=float(input('Enter y: '))
angle=degrees(atan2(y,x))
if x>=0:
    if y>=0:
        quad=1
    else:
        quad=4
else:
    if y>=0:
        quad=2
    else:
        quad=3

print('The angle to the x axis is ',angle)
print('It is in quadrant ', quad)
# Out:
# Enter x: -1
# Enter y: 2
# The angle to the x axis is  116.56505117707799
# It is in quadrant  2

# %%
from math import *
a=float(input('Enter a: '))
b=float(input('Enter b: '))
c=float(input('Enter c: '))
D=b**2-4*a*c
if D>0:
    x1=(-b+sqrt(b**2-4*a*c))/(2*a)
    x2=(-b-sqrt(b**2-4*a*c))/(2*a)
    print(f"The two solutions are {x1} and {x2}")
elif D==0:
    x=-b/(2*a)
    print(f"The solution is {x}")
else:
    print("There are no solutions")
# Out:
# Enter a: 2
# Enter b: -10
# Enter c: 3
# The two solutions are 4.6794494717703365 and 0.320550528229663

# %%
X=[1.36,  1.46,  1.41,  2.12,  0.42,  0.98,  0.45,  1.97, -0.24, 2.18]
X.append(0.51)
X.remove(2.12)
print(f"The value at index 6 is {X[6]}")
print(f"1.46 is at index {X.index(1.46)}")
X_even=X[slice(2,-2,2)]
print(X_even)
X_sum=sum(X_even)
X_len=len(X_even)
X_avg=X_sum/X_len
print(X_avg)
# Out:
# The value at index 6 is 1.97
# 1.46 is at index 1
# [1.41, 0.98, 1.97]
# 1.4533333333333331

# %%
night1 = [1,3,2,4,0,3,7,5,2,9,2,4,3]
night2 = [0,0,2,4,2,4,3,2,1,1,1,2,0]
n1=set(night1)
n2=set(night2)
inter=set.intersection(n1,n2)
print(inter)
if 5 in inter:
    print("5 is an element of the intersection")
else:
    print("5 is not an element of the intersection")

if 5 in night1:
    print("5 is an element of night1")
else:
    print("5 is not an element of night1")
# Out:
# {0, 1, 2, 3, 4}
# 5 is not an element of the intersection
# 5 is an element of night1

# %%
import numpy as np
x=np.array(np.random.normal(0.0,1.4,100000))
dev=np.std(x)
print(dev)
# Out:
# 1.3935288714680334
